# %% [markdown]
# # Travailler sur un fichier annexe
#
# Vous avez besoin de traiter avec Python le contenu d'un fichier (données dans un fichier csv, texte dans un fichier txt) ou une image. Voici comment procéder.
#
# ## Avec un fichier texte (.txt ou .csv)
#
# Dans l'exemple suivant, on charge un fichier csv contenant des données, par exemple issues de data.gouv.fr.
# Ici le fichier contient une liste de médailles aux jeux olympiques d'hiver sur plusieurs années.
#
# Ce fichier a préalablement été déposé dans l'interface capytale, ce qui permet de lui associer une URL publique du type `https://capytale.ac-paris.fr/pj/...`.

# %%
import requests

url = 'https://capytale.ac-paris.fr/pj/75/nicolas.poulain2/medals.csv'
r = requests.get(url)
csv = r.iter_lines()

data = []
for row in csv:
    row = str(row, 'utf-8')
    data.append(row.split(','))

# %% [markdown]
#  Il est maintenant possible de travailler avec les données du fichier chargées dans la variable `data`.

# %%
print(data[0])
print("-------------------------------------")
print(data[10])
print(data[20])
print(data[30])
# Out:
# ['Year', 'City', 'Sport', 'Discipline', 'NOC', 'Event', 'Event gender', 'Medal']
# -------------------------------------
# ['1924', 'Chamonix', 'Skating', 'Speed skating', 'FIN', '1500m', 'M', 'Gold']
# ['1924', 'Chamonix', 'Bobsleigh', 'Bobsleigh', 'GBR', 'four-man', 'M', 'Silver']
# ['1924', 'Chamonix', 'Skating', 'Speed skating', 'NOR', 'combined (4 events)', 'M', 'Silver']

# %% [markdown]
# ## Avec une image
#
# Comme précédemment, on a déposé l'image dans l'interface capytale. On dispose donc d'une URL.
#
# Le chargement puis l'affichage de l'image dans le notebook peut se faire de la manière suivante :

# %%
import requests
from PIL import Image
import io

img_url = "https://capytale.ac-paris.fr/pj/75/luc.baille/joconde.png"
response = requests.get(img_url)
img_data = response.content
img = Image.open(io.BytesIO(img_data))

img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=161x240 at 0x7F240A3F0240>

# %% [markdown]
# Le travail sur l'image devient alors possible.

# %%
import numpy as np
im = np.array(img)

im
# Out:
# array([[[ 90, 103,  83],
#         [ 85, 103,  81],
#         [ 81, 105,  81],
#         ...,
#         [ 67,  82,  61],
#         [ 71,  85,  62],
#         [ 75,  78,  69]],
#
#        [[ 93, 108,  79],
#         [ 89, 108,  78],
#         [ 86, 110,  78],
#         ...,
#         [ 78, 101,  55],
#         [ 83, 102,  56],
#         [ 70,  80,  46]],
#
#        [[ 99, 115,  79],
#         [ 96, 113,  77],
#         [ 94, 116,  78],
#         ...,
#         [ 87, 115,  66],
#         [ 90, 114,  64],
#         [ 98, 107,  90]],
#
#        ...,
#
#        [[ 41,  30,  60],
#         [ 13,   2,  32],
#         [ 21,  10,  40],
#         ...,
#         [ 12,   4,  28],
#         [ 13,   5,  29],
#         [ 28,  20,  43]],
#
#        [[ 57,  51,  79],
#         [ 18,  12,  40],
#         [ 20,  14,  42],
#         ...,
#         [  7,   5,  29],
#         [  9,   7,  31],
#         [ 67,  60,  78]],
#
#        [[ 74,  70,  97],
#         [ 26,  22,  49],
#         [ 22,  18,  45],
#         ...,
#         [ 16,  18,  41],
#         [ 21,  23,  46],
#         [ 79,  75,  90]]], dtype=uint8)
